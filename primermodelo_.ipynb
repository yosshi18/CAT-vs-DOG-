# %% [markdown]
# <a href="https://colab.research.google.com/github/yosshi18/CAT-vs-DOG-/blob/main/primermodelo_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datos = pd.read_csv("celsios.txt")

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Celsius     7 non-null      int64
#  1   fahrenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 244.0 bytes

# %%
datos.head()
# Out:
#    Celsius  fahrenheit
# 0      -40       -40.0
# 1      -10       -14.0
# 2        0        32.0
# 3        8        46.4
# 4       15         5.0

# %%
import seaborn as sb

# %%
sb.scatterplot(x="Celsius",y="fahrenheit", data = datos,
               hue="fahrenheit")
# Out:
# <Axes: xlabel='Celsius', ylabel='fahrenheit'>

# %%
X=datos ["Celsius"]
y=datos ["fahrenheit"]

# %%
y
# Out:
# 0    -40.0
# 1    -14.0
# 2     32.0
# 3     46.4
# 4      5.0
# 5     71.6
# 6    100.4
# Name: fahrenheit, dtype: float64

# %%
X
# Out:
# 0   -40
# 1   -10
# 2     0
# 3     8
# 4    15
# 5    22
# 6    38
# Name: Celsius, dtype: int64

# %%
type(X.values)
# Out:
# numpy.ndarray

# %%
#X.values

X_procesada=X.values.reshape(-1,1)
y_procesada=y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

# %%
modelo.fit(X_procesada, y_procesada)
# Out:
# LinearRegression()

# %%
celsius = 7900
fahrenheit = modelo.predict([[celsius]])
print (f"{celsius} gradoscelsius  son {fahrenheit} grados farenheit" )
# Out:
# 7900 gradoscelsius  son [[13939.22734523]] grados farenheit

# %%
modelo.score(X_procesada, y_procesada)
# Out:
# 0.8102749649519512
